# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import requests
import json
from datetime import date, timedelta
# Out:
# StatementMeta(, 379fb878-5c99-489c-bac7-e42bd32d219e, 3, Finished, Available, Finished, False)

# %%
# Remove this before running Data Factory Pipeline
start_date = date.today() - timedelta(7) # 7 days
end_date = date.today() - timedelta(1)
# Out:
# StatementMeta(, 379fb878-5c99-489c-bac7-e42bd32d219e, 4, Finished, Available, Finished, False)

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"
# Out:
# StatementMeta(, 379fb878-5c99-489c-bac7-e42bd32d219e, 5, Finished, Available, Finished, False)

# %%
url
# Out:
# StatementMeta(, 379fb878-5c99-489c-bac7-e42bd32d219e, 6, Finished, Available, Finished, False)
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2026-04-10&endtime=2026-04-16'

# %%
try:
    # Make the GET request to fetch data
    response = requests.get(url)

    # Check if the request was successful
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    data = response.json().get('features', [])

    if not data:
        print("No data returned for the specified date range.")
    else:
        # Specify the file name (and path if needed)
        file_path = f'/lakehouse/default/Files/{start_date}_earthquake_data.json'

        # Save the JSON data
        with open(file_path, 'w') as file:
            json.dump(data, file, indent=4)
        print(f"Data successfully saved to {file_path}")
except requests.exceptions.RequestException as e:
    print(f"Error fetching data from API: {e}")
# Out:
# StatementMeta(, 379fb878-5c99-489c-bac7-e42bd32d219e, 7, Finished, Available, Finished, False)
# Data successfully saved to /lakehouse/default/Files/2026-04-10_earthquake_data.json

# %%
notebookutils.notebook.exit({"start_date": start_date})
# Out:
# StatementMeta(, 379fb878-5c99-489c-bac7-e42bd32d219e, 8, Finished, Available, Finished, False)
# ExitValue: {'start_date': datetime.date(2026, 4, 10)}
